# %%
# !python -m pip install qiskit
# Out:
# Collecting qiskit
#   Downloading qiskit-2.3.0-cp310-abi3-win_amd64.whl.metadata (13 kB)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Downloading rustworkx-0.17.1-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3,>=1.17 in c:\users\jitesh\lib\site-packages (from qiskit) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in c:\users\jitesh\lib\site-packages (from qiskit) (1.15.3)
# Collecting dill>=0.3 (from qiskit)
#   Downloading dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Downloading stevedore-5.6.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in c:\users\jitesh\lib\site-packages (from qiskit) (4.13.2)
# Downloading qiskit-2.3.0-cp310-abi3-win_amd64.whl (8.6 MB)
#    ---------------------------------------- 0.0/8.6 MB ? eta -:--:--
#    ------------------------- -------------- 5.5/8.6 MB 27.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.6/8.6 MB 25.5 MB/s eta 0:00:00
# Downloading dill-0.4.1-py3-none-any.whl (120 kB)
# Downloading rustworkx-0.17.1-cp39-abi3-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 28.9 MB/s eta 0:00:00
# Downloading stevedore-5.6.0-py3-none-any.whl (54 kB)
# Installing collected packages: stevedore, rustworkx, dill, qiskit
#
#    ---------------------------------------- 0/4 [stevedore]
#    ---------------------------------------- 0/4 [stevedore]
#    ---------------------------------------- 0/4 [stevedore]
#    ---------------------------------------- 0/4 [stevedore]
#    ---------------------------------------- 0/4 [stevedore]
#    ---------------------------------------- 0/4 [stevedore]
#    ---------------------------------------- 0/4 [stevedore]
#    ---------------------------------------- 0/4 [stevedore]
#    ---------------------------------------- 0/4 [stevedore]
#    ---------------------------------------- 0/4 [stevedore]
#    ---------------------------------------- 0/4 [stevedore]
#    ---------------------------------------- 0/4 [stevedore]
#    ---------------------------------------- 0/4 [stevedore]
#    ---------- ----------------------------- 1/4 [rustworkx]
#    -------------------- ------------------- 2/4 [dill]
#    -------------------- ------------------- 2/4 [dill]
#    -------------------- ------------------- 2/4 [dill]
#    -------------------- ------------------- 2/4 [dill]
#    -------------------- ------------------- 2/4 [dill]
#    -------------------- ------------------- 2/4 [dill]
#    -------------------- ------------------- 2/4 [dill]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ------------------------------ --------- 3/4 [qiskit]
#    ---------------------------------------- 4/4 [qiskit]
#
# Successfully installed dill-0.4.1 qiskit-2.3.0 rustworkx-0.17.1 stevedore-5.6.0
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python -m pip install qiskit-aer
# Out:
# Collecting qiskit-aer
#   Downloading qiskit_aer-0.17.2-cp311-cp311-win_amd64.whl.metadata (8.5 kB)
# Requirement already satisfied: qiskit>=1.1.0 in c:\users\jitesh\lib\site-packages (from qiskit-aer) (2.3.0)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\jitesh\lib\site-packages (from qiskit-aer) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in c:\users\jitesh\lib\site-packages (from qiskit-aer) (1.15.3)
# Requirement already satisfied: psutil>=5 in c:\users\jitesh\appdata\roaming\python\python311\site-packages (from qiskit-aer) (5.9.4)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\jitesh\lib\site-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\jitesh\lib\site-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\jitesh\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (0.17.1)
# Requirement already satisfied: dill>=0.3 in c:\users\jitesh\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\jitesh\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (5.6.0)
# Requirement already satisfied: typing-extensions in c:\users\jitesh\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (4.13.2)
# Downloading qiskit_aer-0.17.2-cp311-cp311-win_amd64.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    --------------------------- ------------ 6.6/9.6 MB 33.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 33.1 MB/s eta 0:00:00
# Installing collected packages: qiskit-aer
# Successfully installed qiskit-aer-0.17.2
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python -m pip install matplotlib pylatexenc qiskit[visualization]
# Out:
# Requirement already satisfied: matplotlib in c:\users\jitesh\lib\site-packages (3.7.1)
# Collecting pylatexenc
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: qiskit[visualization] in c:\users\jitesh\lib\site-packages (2.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jitesh\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\jitesh\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jitesh\lib\site-packages (from matplotlib) (4.39.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jitesh\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\jitesh\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\jitesh\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jitesh\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jitesh\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jitesh\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\jitesh\lib\site-packages (from qiskit[visualization]) (0.17.1)
# Requirement already satisfied: scipy>=1.5 in c:\users\jitesh\lib\site-packages (from qiskit[visualization]) (1.15.3)
# Requirement already satisfied: dill>=0.3 in c:\users\jitesh\lib\site-packages (from qiskit[visualization]) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\jitesh\lib\site-packages (from qiskit[visualization]) (5.6.0)
# Requirement already satisfied: typing-extensions in c:\users\jitesh\lib\site-packages (from qiskit[visualization]) (4.13.2)
# Collecting pydot (from qiskit[visualization])
#   Downloading pydot-4.0.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: seaborn>=0.9.0 in c:\users\jitesh\lib\site-packages (from qiskit[visualization]) (0.12.2)
# Requirement already satisfied: sympy>=1.3 in c:\users\jitesh\lib\site-packages (from qiskit[visualization]) (1.14.0)
# Requirement already satisfied: six>=1.5 in c:\users\jitesh\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\jitesh\lib\site-packages (from seaborn>=0.9.0->qiskit[visualization]) (2.3.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jitesh\lib\site-packages (from pandas>=0.25->seaborn>=0.9.0->qiskit[visualization]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jitesh\lib\site-packages (from pandas>=0.25->seaborn>=0.9.0->qiskit[visualization]) (2025.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jitesh\lib\site-packages (from sympy>=1.3->qiskit[visualization]) (1.3.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Downloading pydot-4.0.1-py3-none-any.whl (37 kB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py): started
#   Building wheel for pylatexenc (setup.py): finished with status 'done'
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136848 sha256=98b83401524404fa0493a0e6962dcb93317efd12a61113f1229bfda0c768c9d0
#   Stored in directory: c:\users\jitesh\appdata\local\pip\cache\wheels\b1\7a\33\9fdd892f784ed4afda62b685ae3703adf4c91aa0f524c28f03
# Successfully built pylatexenc
# Installing collected packages: pylatexenc, pyparsing, pydot
#
#    ---------------------------------------- 0/3 [pylatexenc]
#    ---------------------------------------- 0/3 [pylatexenc]
#    ---------------------------------------- 0/3 [pylatexenc]
#    ---------------------------------------- 0/3 [pylatexenc]
#   Attempting uninstall: pyparsing
#    ---------------------------------------- 0/3 [pylatexenc]
#     Found existing installation: pyparsing 3.0.9
#    ---------------------------------------- 0/3 [pylatexenc]
#     Uninstalling pyparsing-3.0.9:
#    ---------------------------------------- 0/3 [pylatexenc]
#       Successfully uninstalled pyparsing-3.0.9
#    ---------------------------------------- 0/3 [pylatexenc]
#    ------------- -------------------------- 1/3 [pyparsing]
#    ------------- -------------------------- 1/3 [pyparsing]
#    -------------------------- ------------- 2/3 [pydot]
#    ---------------------------------------- 3/3 [pydot]
#
# Successfully installed pydot-4.0.1 pylatexenc-2.10 pyparsing-3.3.2
#   DEPRECATION: Building 'pylatexenc' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'pylatexenc'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector

from qiskit.visualization import plot_bloch_multivector,plot_histogram
import matplotlib.pyplot as plt
import numpy as np

qc = QuantumCircuit(3,1)

theta = np.pi/2
phi = np.pi/2

qc.rz(phi,0)
qc.ry(theta,0)



#creating of Bell States
qc.h(1)
qc.cx(1,2)


qc.cx(0,1)
qc.h(0)


qc.cx(1, 2)
qc.cz(0, 2)


qc.ry(-theta,2)
qc.rz(-phi,2)


qc.measure(2,0)

display(qc.draw("mpl"))

sim = AerSimulator()
result = sim.run(qc, shots=5000).result()
counts = result.get_counts()
print("Measurement results (5000 shots):")
print(counts)
plot_histogram(counts)
# Out:
# Measurement results (5000 shots):
# {'0': 5000}

# %%
qc = QuantumCircuit(2,2)

#creating of Bell States
qc.h(0)
qc.cx(0,1)

# qc.x(0)
qc.z(0)


qc.cx(0,1)
qc.h(0)

qc.measure([0,1],[0,1])

display(qc.draw("mpl"))

sim = AerSimulator()
result = sim.run(qc, shots=1).result()
counts = result.get_counts()
print("Measurement results (1 shot):")
print(counts)
plot_histogram(counts)
# Out:
# Measurement results (1 shot):
# {'01': 1}
